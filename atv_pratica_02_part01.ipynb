# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from pyvis import network as net
# Out:
# C:\Users\cacam\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Carregando os datasets
airports = pd.read_csv('../data/airports.csv')
flights = pd.read_csv('../data/flights_names.csv')

# %%
flights.head()
# Out:
#    DayofMonth  DayOfWeek Carrier  airport_id  DepDelay  ArrDelay  \
# 0          19          5      DL       13303        -3         1
# 1          19          5      DL       12478         0        -8
# 2          19          5      DL       14869        -4       -15
# 3          19          5      DL       11433        28        24
# 4          19          5      DL       12892        -6       -11
#
#                                 OriginAirport                    DestAirport
# 0                  Detroit Metro Wayne County            Miami International
# 1                Salt Lake City International  John F. Kennedy International
# 2                      Portland International   Salt Lake City International
# 3             Lambert-St. Louis International     Detroit Metro Wayne County
# 4  Cincinnati/Northern Kentucky International      Los Angeles International

# %%
airports.head()
# Out:
#    airport_id         city state                                 name
# 0       10165  Adak Island    AK                                 Adak
# 1       10299    Anchorage    AK  Ted Stevens Anchorage International
# 2       10304        Aniak    AK                        Aniak Airport
# 3       10754       Barrow    AK      Wiley Post/Will Rogers Memorial
# 4       10551       Bethel    AK                       Bethel Airport

# %%
G = nx.from_pandas_edgelist(flights, source='OriginAirport', target='DestAirport', create_using=nx.DiGraph())

# %%
nx.write_graphml(G, 'airports-network.graphml')

# %%
pos = nx.spring_layout(G)

fig, ax = plt.subplots()

nx.draw(G, pos, with_labels=True, node_size=500, font_size=8, font_color="black", font_weight="bold", edge_color="gray", ax=ax)

plt.show()

# %% [markdown]
# ### Calculate Degree
# Who has the most number of connections in the network?

# %%
nx.degree(G)
# Out:
# DiDegreeView({'Detroit Metro Wayne County': 106, 'Miami International': 80, 'Salt Lake City International': 94, 'John F. Kennedy International': 108, 'Portland International': 74, 'Lambert-St. Louis International': 87, 'Cincinnati/Northern Kentucky International': 80, 'Los Angeles International': 108, 'Hartsfield-Jackson Atlanta International': 126, 'Austin - Bergstrom International': 70, 'Ronald Reagan Washington National': 81, 'Phoenix Sky Harbor International': 118, 'Minneapolis-St Paul International': 116, 'Dallas/Fort Worth International': 124, 'Jacksonville International': 48, 'LaGuardia': 77, 'San Francisco International': 97, 'Orlando International': 100, 'McCarran International': 118, 'Palm Beach International': 38, 'Memphis International': 77, 'Fort Lauderdale-Hollywood International': 86, 'Seattle/Tacoma International': 98, 'Denver International': 124, 'Sacramento International': 50, 'John Wayne Airport-Orange County': 36, 'Tampa International': 86, 'Kansas City International': 79, 'Charlotte Douglas International': 110, 'Philadelphia International': 95, 'San Antonio International': 56, 'Nashville International': 84, 'Indianapolis International': 58, 'George Bush Intercontinental/Houston': 120, 'Southwest Florida International': 54, "Chicago O'Hare International": 123, 'San Diego International': 80, 'Logan International': 104, 'Baltimore/Washington International Thurgood Marshall': 100, 'Norfolk International': 38, 'Port Columbus International': 55, 'Louis Armstrong New Orleans International': 70, 'Albuquerque International Sunport': 48, 'Buffalo Niagara International': 38, 'Raleigh-Durham International': 69, 'Tucson International': 30, 'Honolulu International': 42, 'Newark Liberty International': 113, 'General Mitchell International': 58, 'Louisville International-Standiford Field': 45, 'Norman Y. Mineta San Jose International': 44, 'Pittsburgh International': 64, 'Cleveland-Hopkins International': 94, 'Ted Stevens Anchorage International': 32, 'Richmond International': 36, 'Luis Munoz Marin International': 40, 'Bradley International': 50, 'Chicago Midway International': 104, 'Theodore Francis Green State': 36, 'Eppley Airfield': 37, 'Reno/Tahoe International': 28, 'Washington Dulles International': 102, 'Kahului Airport': 27, 'William P Hobby': 70, 'Metropolitan Oakland International': 46, 'Will Rogers World': 46, 'Long Beach Airport': 26, 'Dallas Love Field': 20, 'Bob Hope': 22, 'Ontario International': 26})

# %%
degrees = dict(nx.degree(G))
nx.set_node_attributes(G, name='degree', values=degrees)

# %%
degree_df = pd.DataFrame(G.nodes(data='degree'), columns=['node', 'degree'])
degree_df = degree_df.sort_values(by='degree', ascending=False)
degree_df
# Out:
#                                         node  degree
# 8   Hartsfield-Jackson Atlanta International     126
# 23                      Denver International     124
# 13           Dallas/Fort Worth International     124
# 35              Chicago O'Hare International     123
# 33      George Bush Intercontinental/Houston     120
# ..                                       ...     ...
# 62                           Kahului Airport      27
# 66                        Long Beach Airport      26
# 69                     Ontario International      26
# 68                                  Bob Hope      22
# 67                         Dallas Love Field      20
#
# [70 rows x 2 columns]

# %%
num_nodes_to_inspect = 10
degree_df[:num_nodes_to_inspect].plot(x='node', y='degree', kind='barh').invert_yaxis()

# %% [markdown]
# ### Calculate Betweenness Centrality Scores
# Who connects the most other nodes in the network?

# %%
nx.betweenness_centrality(G)
# Out:
# {'Detroit Metro Wayne County': 0.010093852814680565,
#  'Miami International': 0.0034277564547492735,
#  'Salt Lake City International': 0.013116612148662388,
#  'John F. Kennedy International': 0.02067271166684944,
#  'Portland International': 0.007034522355726602,
#  'Lambert-St. Louis International': 0.005627053742568737,
#  'Cincinnati/Northern Kentucky International': 0.002453174237426553,
#  'Los Angeles International': 0.01497478740633381,
#  'Hartsfield-Jackson Atlanta International': 0.02903778352212746,
#  'Austin - Bergstrom International': 0.0047978449009147255,
#  'Ronald Reagan Washington National': 0.003873587465185673,
#  'Phoenix Sky Harbor International': 0.025602715446013762,
#  'Minneapolis-St Paul International': 0.017535638149935844,
#  'Dallas/Fort Worth International': 0.029481541880603725,
#  'Jacksonville International': 0.0006533105824873239,
#  'LaGuardia': 0.004635646613554912,
#  'San Francisco International': 0.014755059829132153,
#  'Orlando International': 0.009168957968307011,
#  'McCarran International': 0.023858722642235448,
#  'Palm Beach International': 0.0005187293402421687,
#  'Memphis International': 0.0023489814340201635,
#  'Fort Lauderdale-Hollywood International': 0.004729729817098423,
#  'Seattle/Tacoma International': 0.014671536023656331,
#  'Denver International': 0.029825141780960757,
#  'Sacramento International': 0.0025304447905057812,
#  'John Wayne Airport-Orange County': 0.00048449960231842544,
#  'Tampa International': 0.004801365457902712,
#  'Kansas City International': 0.004578214227734775,
#  'Charlotte Douglas International': 0.011936523278128032,
#  'Philadelphia International': 0.006983183220038019,
#  'San Antonio International': 0.0015020250826211494,
#  'Nashville International': 0.0027870457651059236,
#  'Indianapolis International': 0.0006715524627701024,
#  'George Bush Intercontinental/Houston': 0.028829697070273497,
#  'Southwest Florida International': 0.0013083864081478178,
#  "Chicago O'Hare International": 0.026396526493047783,
#  'San Diego International': 0.005759236969409441,
#  'Logan International': 0.012797363740699275,
#  'Baltimore/Washington International Thurgood Marshall': 0.009130549648995293,
#  'Norfolk International': 0.00014579033030329649,
#  'Port Columbus International': 0.0003525366208488001,
#  'Louis Armstrong New Orleans International': 0.002382567431767007,
#  'Albuquerque International Sunport': 0.001814777989148433,
#  'Buffalo Niagara International': 0.00021416523466414298,
#  'Raleigh-Durham International': 0.0009667926550799694,
#  'Tucson International': 2.646757130234147e-05,
#  'Honolulu International': 0.0008053233363139245,
#  'Newark Liberty International': 0.016431061477145594,
#  'General Mitchell International': 0.0004322772627512082,
#  'Louisville International-Standiford Field': 0.00016262411851769462,
#  'Norman Y. Mineta San Jose International': 0.001704128090771534,
#  'Pittsburgh International': 0.0012451326531824683,
#  'Cleveland-Hopkins International': 0.006730040250155616,
#  'Ted Stevens Anchorage International': 0.0006131726555368956,
#  'Richmond International': 5.39931070198825e-05,
#  'Luis Munoz Marin International': 0.00038952764424348427,
#  'Bradley International': 0.0007882430301069641,
#  'Chicago Midway International': 0.019701420684818005,
#  'Theodore Francis Green State': 0.00031663784415920585,
#  'Eppley Airfield': 0.0001043062791805845,
#  'Reno/Tahoe International': 0.00011521422240795151,
#  'Washington Dulles International': 0.015091677067792339,
#  'Kahului Airport': 0.00028035014871181566,
#  'William P Hobby': 0.005373028369203312,
#  'Metropolitan Oakland International': 0.0031078536514554922,
#  'Will Rogers World': 0.0010666074968568211,
#  'Long Beach Airport': 0.00031102936925112343,
#  'Dallas Love Field': 0.000269837464840913,
#  'Bob Hope': 0.00011021148752456109,
#  'Ontario International': 0.000172973769948066}

# %%
betweenness_centrality = nx.betweenness_centrality(G)

# %%
nx.set_node_attributes(G, name='betweenness', values=betweenness_centrality)

# %%
betweenness_df = pd.DataFrame(G.nodes(data='betweenness'), columns=['node', 'betweenness'])
betweenness_df = betweenness_df.sort_values(by='betweenness', ascending=False)
betweenness_df
# Out:
#                                         node  betweenness
# 23                      Denver International     0.029825
# 13           Dallas/Fort Worth International     0.029482
# 8   Hartsfield-Jackson Atlanta International     0.029038
# 33      George Bush Intercontinental/Houston     0.028830
# 35              Chicago O'Hare International     0.026397
# ..                                       ...          ...
# 60                  Reno/Tahoe International     0.000115
# 68                                  Bob Hope     0.000110
# 59                           Eppley Airfield     0.000104
# 54                    Richmond International     0.000054
# 45                      Tucson International     0.000026
#
# [70 rows x 2 columns]

# %%
num_nodes_to_inspect = 10
betweenness_df[:num_nodes_to_inspect].plot(x='node', y='betweenness', color='green', kind='barh').invert_yaxis()

# %% [markdown]
# ### Communities
# Who forms distinct communities within this network?

# %%
from networkx.algorithms import community

# %%
communities = community.greedy_modularity_communities(G)

# %%
communities
# Out:
# [frozenset({'Baltimore/Washington International Thurgood Marshall',
#             'Bradley International',
#             'Buffalo Niagara International',
#             'Charlotte Douglas International',
#             "Chicago O'Hare International",
#             'Cincinnati/Northern Kentucky International',
#             'Cleveland-Hopkins International',
#             'Dallas Love Field',
#             'Detroit Metro Wayne County',
#             'Fort Lauderdale-Hollywood International',
#             'General Mitchell International',
#             'George Bush Intercontinental/Houston',
#             'Hartsfield-Jackson Atlanta International',
#             'Indianapolis International',
#             'Jacksonville International',
#             'John F. Kennedy International',
#             'Kansas City International',
#             'LaGuardia',
#             'Lambert-St. Louis International',
#             'Logan International',
#             'Louis Armstrong New Orleans International',
#             'Louisville International-Standiford Field',
#             'Luis Munoz Marin International',
#             'Memphis International',
#             'Miami International',
#             'Minneapolis-St Paul International',
#             'Nashville International',
#             'Newark Liberty International',
#             'Norfolk International',
#             'Orlando International',
#             'Palm Beach International',
#             'Philadelphia International',
#             'Pittsburgh International',
#             'Port Columbus International',
#             'Raleigh-Durham International',
#             'Richmond International',
#             'Ronald Reagan Washington National',
#             'San Antonio International',
#             'Southwest Florida International',
#             'Tampa International',
#             'Theodore Francis Green State',
#             'Washington Dulles International',
#             'Will Rogers World',
#             'William P Hobby'}),
#  frozenset({'Albuquerque International Sunport',
#             'Austin - Bergstrom International',
#             'Bob Hope',
#             'Chicago Midway International',
#             'Dallas/Fort Worth International',
#             'Denver International',
#             'Eppley Airfield',
#             'Honolulu International',
#             'John Wayne Airport-Orange County',
#             'Kahului Airport',
#             'Long Beach Airport',
#             'Los Angeles International',
#             'McCarran International',
#             'Metropolitan Oakland International',
#             'Norman Y. Mineta San Jose International',
#             'Ontario International',
#             'Phoenix Sky Harbor International',
#             'Portland International',
#             'Reno/Tahoe International',
#             'Sacramento International',
#             'Salt Lake City International',
#             'San Diego International',
#             'San Francisco International',
#             'Seattle/Tacoma International',
#             'Ted Stevens Anchorage International',
#             'Tucson International'})]

# %%
# Create empty dictionary
modularity_class = {}
#Loop through each community in the network
for community_number, community in enumerate(communities):
    #For each member of the community, add their community number
    for name in community:
        modularity_class[name] = community_number

# %%
nx.set_node_attributes(G, modularity_class, 'modularity_class')

# %%
communities_df = pd.DataFrame(G.nodes(data='modularity_class'), columns=['node', 'modularity_class'])
communities_df = communities_df.sort_values(by='modularity_class', ascending=False)

# %%
communities_df
# Out:
#                                                  node  modularity_class
# 69                              Ontario International                 1
# 62                                    Kahului Airport                 1
# 53                Ted Stevens Anchorage International                 1
# 25                   John Wayne Airport-Orange County                 1
# 24                           Sacramento International                 1
# ..                                                ...               ...
# 1                                 Miami International                 0
# 37                                Logan International                 0
# 38  Baltimore/Washington International Thurgood Ma...                 0
# 39                              Norfolk International                 0
# 35                       Chicago O'Hare International                 0
#
# [70 rows x 2 columns]

# %%
dict(G.nodes(data=True))
# Out:
# {'Detroit Metro Wayne County': {'degree': 106,
#   'betweenness': 0.010093852814680565,
#   'modularity_class': 0},
#  'Miami International': {'degree': 80,
#   'betweenness': 0.0034277564547492735,
#   'modularity_class': 0},
#  'Salt Lake City International': {'degree': 94,
#   'betweenness': 0.013116612148662388,
#   'modularity_class': 1},
#  'John F. Kennedy International': {'degree': 108,
#   'betweenness': 0.02067271166684944,
#   'modularity_class': 0},
#  'Portland International': {'degree': 74,
#   'betweenness': 0.007034522355726602,
#   'modularity_class': 1},
#  'Lambert-St. Louis International': {'degree': 87,
#   'betweenness': 0.005627053742568737,
#   'modularity_class': 0},
#  'Cincinnati/Northern Kentucky International': {'degree': 80,
#   'betweenness': 0.002453174237426553,
#   'modularity_class': 0},
#  'Los Angeles International': {'degree': 108,
#   'betweenness': 0.01497478740633381,
#   'modularity_class': 1},
#  'Hartsfield-Jackson Atlanta International': {'degree': 126,
#   'betweenness': 0.02903778352212746,
#   'modularity_class': 0},
#  'Austin - Bergstrom International': {'degree': 70,
#   'betweenness': 0.0047978449009147255,
#   'modularity_class': 1},
#  'Ronald Reagan Washington National': {'degree': 81,
#   'betweenness': 0.003873587465185673,
#   'modularity_class': 0},
#  'Phoenix Sky Harbor International': {'degree': 118,
#   'betweenness': 0.025602715446013762,
#   'modularity_class': 1},
#  'Minneapolis-St Paul International': {'degree': 116,
#   'betweenness': 0.017535638149935844,
#   'modularity_class': 0},
#  'Dallas/Fort Worth International': {'degree': 124,
#   'betweenness': 0.029481541880603725,
#   'modularity_class': 1},
#  'Jacksonville International': {'degree': 48,
#   'betweenness': 0.0006533105824873239,
#   'modularity_class': 0},
#  'LaGuardia': {'degree': 77,
#   'betweenness': 0.004635646613554912,
#   'modularity_class': 0},
#  'San Francisco International': {'degree': 97,
#   'betweenness': 0.014755059829132153,
#   'modularity_class': 1},
#  'Orlando International': {'degree': 100,
#   'betweenness': 0.009168957968307011,
#   'modularity_class': 0},
#  'McCarran International': {'degree': 118,
#   'betweenness': 0.023858722642235448,
#   'modularity_class': 1},
#  'Palm Beach International': {'degree': 38,
#   'betweenness': 0.0005187293402421687,
#   'modularity_class': 0},
#  'Memphis International': {'degree': 77,
#   'betweenness': 0.0023489814340201635,
#   'modularity_class': 0},
#  'Fort Lauderdale-Hollywood International': {'degree': 86,
#   'betweenness': 0.004729729817098423,
#   'modularity_class': 0},
#  'Seattle/Tacoma International': {'degree': 98,
#   'betweenness': 0.014671536023656331,
#   'modularity_class': 1},
#  'Denver International': {'degree': 124,
#   'betweenness': 0.029825141780960757,
#   'modularity_class': 1},
#  'Sacramento International': {'degree': 50,
#   'betweenness': 0.0025304447905057812,
#   'modularity_class': 1},
#  'John Wayne Airport-Orange County': {'degree': 36,
#   'betweenness': 0.00048449960231842544,
#   'modularity_class': 1},
#  'Tampa International': {'degree': 86,
#   'betweenness': 0.004801365457902712,
#   'modularity_class': 0},
#  'Kansas City International': {'degree': 79,
#   'betweenness': 0.004578214227734775,
#   'modularity_class': 0},
#  'Charlotte Douglas International': {'degree': 110,
#   'betweenness': 0.011936523278128032,
#   'modularity_class': 0},
#  'Philadelphia International': {'degree': 95,
#   'betweenness': 0.006983183220038019,
#   'modularity_class': 0},
#  'San Antonio International': {'degree': 56,
#   'betweenness': 0.0015020250826211494,
#   'modularity_class': 0},
#  'Nashville International': {'degree': 84,
#   'betweenness': 0.0027870457651059236,
#   'modularity_class': 0},
#  'Indianapolis International': {'degree': 58,
#   'betweenness': 0.0006715524627701024,
#   'modularity_class': 0},
#  'George Bush Intercontinental/Houston': {'degree': 120,
#   'betweenness': 0.028829697070273497,
#   'modularity_class': 0},
#  'Southwest Florida International': {'degree': 54,
#   'betweenness': 0.0013083864081478178,
#   'modularity_class': 0},
#  "Chicago O'Hare International": {'degree': 123,
#   'betweenness': 0.026396526493047783,
#   'modularity_class': 0},
#  'San Diego International': {'degree': 80,
#   'betweenness': 0.005759236969409441,
#   'modularity_class': 1},
#  'Logan International': {'degree': 104,
#   'betweenness': 0.012797363740699275,
#   'modularity_class': 0},
#  'Baltimore/Washington International Thurgood Marshall': {'degree': 100,
#   'betweenness': 0.009130549648995293,
#   'modularity_class': 0},
#  'Norfolk International': {'degree': 38,
#   'betweenness': 0.00014579033030329649,
#   'modularity_class': 0},
#  'Port Columbus International': {'degree': 55,
#   'betweenness': 0.0003525366208488001,
#   'modularity_class': 0},
#  'Louis Armstrong New Orleans International': {'degree': 70,
#   'betweenness': 0.002382567431767007,
#   'modularity_class': 0},
#  'Albuquerque International Sunport': {'degree': 48,
#   'betweenness': 0.001814777989148433,
#   'modularity_class': 1},
#  'Buffalo Niagara International': {'degree': 38,
#   'betweenness': 0.00021416523466414298,
#   'modularity_class': 0},
#  'Raleigh-Durham International': {'degree': 69,
#   'betweenness': 0.0009667926550799694,
#   'modularity_class': 0},
#  'Tucson International': {'degree': 30,
#   'betweenness': 2.646757130234147e-05,
#   'modularity_class': 1},
#  'Honolulu International': {'degree': 42,
#   'betweenness': 0.0008053233363139245,
#   'modularity_class': 1},
#  'Newark Liberty International': {'degree': 113,
#   'betweenness': 0.016431061477145594,
#   'modularity_class': 0},
#  'General Mitchell International': {'degree': 58,
#   'betweenness': 0.0004322772627512082,
#   'modularity_class': 0},
#  'Louisville International-Standiford Field': {'degree': 45,
#   'betweenness': 0.00016262411851769462,
#   'modularity_class': 0},
#  'Norman Y. Mineta San Jose International': {'degree': 44,
#   'betweenness': 0.001704128090771534,
#   'modularity_class': 1},
#  'Pittsburgh International': {'degree': 64,
#   'betweenness': 0.0012451326531824683,
#   'modularity_class': 0},
#  'Cleveland-Hopkins International': {'degree': 94,
#   'betweenness': 0.006730040250155616,
#   'modularity_class': 0},
#  'Ted Stevens Anchorage International': {'degree': 32,
#   'betweenness': 0.0006131726555368956,
#   'modularity_class': 1},
#  'Richmond International': {'degree': 36,
#   'betweenness': 5.39931070198825e-05,
#   'modularity_class': 0},
#  'Luis Munoz Marin International': {'degree': 40,
#   'betweenness': 0.00038952764424348427,
#   'modularity_class': 0},
#  'Bradley International': {'degree': 50,
#   'betweenness': 0.0007882430301069641,
#   'modularity_class': 0},
#  'Chicago Midway International': {'degree': 104,
#   'betweenness': 0.019701420684818005,
#   'modularity_class': 1},
#  'Theodore Francis Green State': {'degree': 36,
#   'betweenness': 0.00031663784415920585,
#   'modularity_class': 0},
#  'Eppley Airfield': {'degree': 37,
#   'betweenness': 0.0001043062791805845,
#   'modularity_class': 1},
#  'Reno/Tahoe International': {'degree': 28,
#   'betweenness': 0.00011521422240795151,
#   'modularity_class': 1},
#  'Washington Dulles International': {'degree': 102,
#   'betweenness': 0.015091677067792339,
#   'modularity_class': 0},
#  'Kahului Airport': {'degree': 27,
#   'betweenness': 0.00028035014871181566,
#   'modularity_class': 1},
#  'William P Hobby': {'degree': 70,
#   'betweenness': 0.005373028369203312,
#   'modularity_class': 0},
#  'Metropolitan Oakland International': {'degree': 46,
#   'betweenness': 0.0031078536514554922,
#   'modularity_class': 1},
#  'Will Rogers World': {'degree': 46,
#   'betweenness': 0.0010666074968568211,
#   'modularity_class': 0},
#  'Long Beach Airport': {'degree': 26,
#   'betweenness': 0.00031102936925112343,
#   'modularity_class': 1},
#  'Dallas Love Field': {'degree': 20,
#   'betweenness': 0.000269837464840913,
#   'modularity_class': 0},
#  'Bob Hope': {'degree': 22,
#   'betweenness': 0.00011021148752456109,
#   'modularity_class': 1},
#  'Ontario International': {'degree': 26,
#   'betweenness': 0.000172973769948066,
#   'modularity_class': 1}}

# %%
nodes_df = pd.DataFrame(dict(G.nodes(data=True))).T
nodes_df
# Out:
#                                degree  betweenness  modularity_class
# Detroit Metro Wayne County      106.0     0.010094               0.0
# Miami International              80.0     0.003428               0.0
# Salt Lake City International     94.0     0.013117               1.0
# John F. Kennedy International   108.0     0.020673               0.0
# Portland International           74.0     0.007035               1.0
# ...                               ...          ...               ...
# Will Rogers World                46.0     0.001067               0.0
# Long Beach Airport               26.0     0.000311               1.0
# Dallas Love Field                20.0     0.000270               0.0
# Bob Hope                         22.0     0.000110               1.0
# Ontario International            26.0     0.000173               1.0
#
# [70 rows x 3 columns]

# %%
nodes_df.sort_values(by='betweenness', ascending=False)
# Out:
#                                           degree  betweenness  \
# Denver International                       124.0     0.029825
# Dallas/Fort Worth International            124.0     0.029482
# Hartsfield-Jackson Atlanta International   126.0     0.029038
# George Bush Intercontinental/Houston       120.0     0.028830
# Chicago O'Hare International               123.0     0.026397
# ...                                          ...          ...
# Reno/Tahoe International                    28.0     0.000115
# Bob Hope                                    22.0     0.000110
# Eppley Airfield                             37.0     0.000104
# Richmond International                      36.0     0.000054
# Tucson International                        30.0     0.000026
#
#                                           modularity_class
# Denver International                                   1.0
# Dallas/Fort Worth International                        1.0
# Hartsfield-Jackson Atlanta International               0.0
# George Bush Intercontinental/Houston                   0.0
# Chicago O'Hare International                           0.0
# ...                                                    ...
# Reno/Tahoe International                               1.0
# Bob Hope                                               1.0
# Eppley Airfield                                        1.0
# Richmond International                                 0.0
# Tucson International                                   1.0
#
# [70 rows x 3 columns]

# %%
g = net.Network(notebook=True)
nxg = nx.complete_graph(5)
g.from_nx(nxg)
g.show('example.html')
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# example.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="example.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
